# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from zipfile import ZipFile
file_name = "/content/drive/MyDrive/covid_data/CovidDataset.zip"
with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print("Completed")
# Out:
# Completed

# %%
from tensorflow.keras.layers import *
from tensorflow.keras.models import *

# %%
#Training model
model = Sequential()   ## creating a blank model
model.add(Conv2D(32,kernel_size=(3,3),activation='relu',input_shape=(224,224,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))    ### reduce the overfitting
 
model.add(Conv2D(64,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
 
model.add(Conv2D(128,(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))
 
model.add(Flatten())    ### input layer
model.add(Dense(64,activation='relu'))    ## hidden layer of ann
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))   ## output layer
 
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
#Moulding train images
from tensorflow.keras.preprocessing import image
train_datagen = image.ImageDataGenerator(rescale = 1./255, shear_range = 0.2,zoom_range = 0.2, horizontal_flip = True)
 
test_dataset = image.ImageDataGenerator(rescale=1./255)

# %%
#Reshaping test and validation images 
train_generator = train_datagen.flow_from_directory(
    '/content/CovidDataset/Train',
    target_size = (224,224),
    batch_size = 32,
    class_mode = 'binary')
validation_generator = test_dataset.flow_from_directory(
    '/content/CovidDataset/Val',
    target_size = (224,224),
    batch_size = 32,
    class_mode = 'binary')
# Out:
# Found 224 images belonging to 2 classes.
# Found 60 images belonging to 2 classes.

# %%
#### Train the model
history = model.fit_generator(
    train_generator,
    steps_per_epoch=7,
    epochs = 20,
    validation_data = validation_generator,
    validation_steps=1
)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/20
# 7/7 [==============================] - 14s 1s/step - loss: 0.7157 - accuracy: 0.5664 - val_loss: 0.6858 - val_accuracy: 0.5625
# Epoch 2/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.6791 - accuracy: 0.5695 - val_loss: 0.6216 - val_accuracy: 0.7812
# Epoch 3/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.4872 - accuracy: 0.7993 - val_loss: 0.2791 - val_accuracy: 0.9688
# Epoch 4/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.2855 - accuracy: 0.8994 - val_loss: 0.1113 - val_accuracy: 0.9688
# Epoch 5/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.2236 - accuracy: 0.9006 - val_loss: 0.2300 - val_accuracy: 0.9688
# Epoch 6/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.2027 - accuracy: 0.9185 - val_loss: 0.1851 - val_accuracy: 0.9688
# Epoch 7/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.1488 - accuracy: 0.9275 - val_loss: 0.0840 - val_accuracy: 0.9375
# Epoch 8/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.1019 - accuracy: 0.9701 - val_loss: 0.0139 - val_accuracy: 1.0000
# Epoch 9/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.1950 - accuracy: 0.9249 - val_loss: 0.0905 - val_accuracy: 0.9688
# Epoch 10/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.1775 - accuracy: 0.9606 - val_loss: 0.0605 - val_accuracy: 1.0000
# Epoch 11/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.0965 - accuracy: 0.9556 - val_loss: 0.0240 - val_accuracy: 1.0000
# Epoch 12/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.1300 - accuracy: 0.9604 - val_loss: 0.0417 - val_accuracy: 1.0000
# Epoch 13/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.1838 - accuracy: 0.9505 - val_loss: 0.0703 - val_accuracy: 1.0000
# Epoch 14/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.1972 - accuracy: 0.9491 - val_loss: 0.1135 - val_accuracy: 1.0000
# Epoch 15/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.1615 - accuracy: 0.9507 - val_loss: 0.0538 - val_accuracy: 1.0000
# Epoch 16/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.1257 - accuracy: 0.9459 - val_loss: 0.0538 - val_accuracy: 0.9688
# Epoch 17/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.0827 - accuracy: 0.9564 - val_loss: 0.0482 - val_accuracy: 0.9688
# Epoch 18/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.1029 - accuracy: 0.9679 - val_loss: 0.0539 - val_accuracy: 1.0000
# Epoch 19/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.0959 - accuracy: 0.9550 - val_loss: 0.0402 - val_accuracy: 1.0000
# Epoch 20/20
# 7/7 [==============================] - 8s 1s/step - loss: 0.1701 - accuracy: 0.9400 - val_loss: 0.1052 - val_accuracy: 0.9688

# %%
print("We are learning Numpy")   ## shift + enter to run
# Out:
# We are learning Numpy

# %%
import numpy as np

# %%
### Create an Array (2D Array)

# %%
a1 = np.array([[4,8,9],[8,9,6],[2,3,6],[7,6,5],[1,3,5]])
a1

# %%
a1.shape

# %%
a1.ndim

# %%
a1.dtype

# %%
a1.max()

# %%
a1.min()

# %%
a1

# %%
a1.argmax()

# %%
a1.argmin()

# %%
a1.sum()
# Out:
# 82

# %%
a1.sum(axis=0)  ## column wise addition

# %%
a1.sum(axis=1)  ## row wise addition

# %%
### Picking any element from array (slicing of array)

# %%
a1

# %%
a1[3]

# %%
a1[:]

# %%
a1[2:5]   ## index 2 to index 4

# %%
a1[:4]    ## index 0 to index 3

# %%
a1[3:]   ## index 3 to last

# %%
a1

# %%
a1[1]

# %%
a1[1][1]

# %%
a1[1,1]

# %%
a1[1:4,1:3]

# %%
### Linspace Function - Generate equidistant number

# %%
a2 = np.linspace(1,100,30)   ## (start,stop,no.of samples)
#a2 = a2.astype('int')
a2

# %%
a2 = np.linspace(1,100,10)
a2

# %%
a2=np.linspace(1,10,3)
a2

# %%
### Arange Function
a3 = np.arange(1,102,5)   #(start,stop,difference)
a3

# %%
len(a3)

# %%
a4=np.arange(1,100,5)
a4
# Out:
# array([ 1,  6, 11, 16, 21, 26, 31, 36, 41, 46, 51, 56, 61, 66, 71, 76, 81,
#        86, 91, 96])

# %%
### Random Numbers

# %%
np.random.randint(100)   ## any random number b/w 0-99

# %%
np.random.seed(2)
np.random.randint(100)
# Out:
# 40

# %%
np.random.randint(10000,200000)   ## any random number b/w 10000-199999
# Out:
# 105816

# %%
np.random.randint(10,1000,10)
# Out:
# array([309, 476,  85, 370, 273, 684, 443, 617, 597, 735])

# %%
np.random.seed(2)
np.random.randint(10,1000,(4,5))   ## random array (4x5)
# Out:
# array([[178, 537, 503, 594, 544],
#        [309, 476,  85, 370, 273],
#        [684, 443, 617, 597, 735],
#        [ 57, 841, 297, 740, 414]])
